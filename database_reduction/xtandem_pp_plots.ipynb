# %% [markdown]
# # X!Tandem

# %% [markdown]
# ## Read with PSM Utils

# %%
#!pip install psm-utils==0.6.1 
# in newer versions, there's a bug
#!pip install -U kaleido
#!pip install matplotlib
#!pip install --upgrade nbformat
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 5.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.9.2
#     Uninstalling nbformat-5.9.2:
#       Successfully uninstalled nbformat-5.9.2
# ...

# %%
from psm_utils.io.xtandem import XTandemReader
from psm_utils.psm_list import PSMList
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.io as pio

# %%
# Read the F07 standard search files
tandem_f_F07_1 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction1_target_decoy_concat.2024_03_07_17_50_51.t.xml"
tandem_f_F07_2 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction2_target_decoy_concat.2024_03_07_18_22_03.t.xml"
tandem_f_F07_3 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction3_target_decoy_concat.2024_03_07_18_54_33.t.xml"
tandem_f_F07_4 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction4_target_decoy_concat.2024_03_07_19_21_21.t.xml"


reader_F07_1 = XTandemReader(tandem_f_F07_1)
reader_F07_2 = XTandemReader(tandem_f_F07_2)
reader_F07_3 = XTandemReader(tandem_f_F07_3)
reader_F07_4 = XTandemReader(tandem_f_F07_4)


psm_list_F07_1 = reader_F07_1.read_file()
psm_list_F07_2 = reader_F07_2.read_file()
psm_list_F07_3 = reader_F07_3.read_file()
psm_list_F07_4 = reader_F07_4.read_file()

# %%
# Read the S11 standard search files
tandem_f_S11_1 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction1_target_decoy_concat.2024_03_07_19_21_59.t.xml"
tandem_f_S11_2 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction2_target_decoy_concat.2024_03_07_19_22_27.t.xml"
tandem_f_S11_3 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction3_target_decoy_concat.2024_03_07_19_22_58.t.xml"
tandem_f_S11_4 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction4_target_decoy_concat.2024_03_07_19_23_16.t.xml"


reader_S11_1 = XTandemReader(tandem_f_S11_1)
reader_S11_2 = XTandemReader(tandem_f_S11_2)
reader_S11_3 = XTandemReader(tandem_f_S11_3)
reader_S11_4 = XTandemReader(tandem_f_S11_4)


psm_list_S11_1 = reader_S11_1.read_file()
psm_list_S11_2 = reader_S11_2.read_file()
psm_list_S11_3 = reader_S11_3.read_file()
psm_list_S11_4 = reader_S11_4.read_file()

# %%
# Read the F07 two-step search files
tandem_f_two_step_F07_1 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction1_2nd_step_td_concat.2024_03_08_17_53_24.t.xml"
tandem_f_two_step_F07_2 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction2_2nd_step_td_concat.2024_03_08_17_54_31.t.xml"
tandem_f_two_step_F07_3 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction3_2nd_step_td_concat.2024_03_08_17_55_49.t.xml"
tandem_f_two_step_F07_4 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction4_2nd_step_td_concat.2024_03_08_17_56_56.t.xml"


reader_two_step_F07_1 = XTandemReader(tandem_f_two_step_F07_1)
reader_two_step_F07_2 = XTandemReader(tandem_f_two_step_F07_2)
reader_two_step_F07_3 = XTandemReader(tandem_f_two_step_F07_3)
reader_two_step_F07_4 = XTandemReader(tandem_f_two_step_F07_4)


psm_list_two_step_F07_1 = reader_two_step_F07_1.read_file()
psm_list_two_step_F07_2 = reader_two_step_F07_2.read_file()
psm_list_two_step_F07_3 = reader_two_step_F07_3.read_file()
psm_list_two_step_F07_4 = reader_two_step_F07_4.read_file()

# %%
# Read the S11 two-step search files
tandem_f_two_step_S11_1 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction1_2nd_step.2024_03_07_13_17_47.t.xml"
tandem_f_two_step_S11_2 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction2_2nd_step.2024_03_07_13_18_14.t.xml"
tandem_f_two_step_S11_3 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction3_2nd_step.2024_03_07_13_18_44.t.xml"
tandem_f_two_step_S11_4 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction4_2nd_step.2024_03_07_13_19_05.t.xml"

reader_two_step_S11_1 = XTandemReader(tandem_f_two_step_S11_1)
reader_two_step_S11_2 = XTandemReader(tandem_f_two_step_S11_2)
reader_two_step_S11_3 = XTandemReader(tandem_f_two_step_S11_3)
reader_two_step_S11_4 = XTandemReader(tandem_f_two_step_S11_4)

psm_list_two_step_S11_1 = reader_two_step_S11_1.read_file()
psm_list_two_step_S11_2 = reader_two_step_S11_2.read_file()
psm_list_two_step_S11_3 = reader_two_step_S11_3.read_file()
psm_list_two_step_S11_4 = reader_two_step_S11_4.read_file()

# %%
# Concatenate the PSM lists into one object
psm_list_F = psm_list_F07_1 + psm_list_F07_2 + psm_list_F07_3 + psm_list_F07_4

# %%
# Concatenate the PSM lists into one object
psm_list_S = psm_list_S11_1 + psm_list_S11_2 + psm_list_S11_3 + psm_list_S11_4

# %%
# Concatenate the PSM lists into one object
psm_list_two_step_F = psm_list_two_step_F07_1 + psm_list_two_step_F07_2 + psm_list_two_step_F07_3 + psm_list_two_step_F07_4

# %%
# Concatenate the PSM lists into one object
psm_list_two_step_S = psm_list_two_step_S11_1 + psm_list_two_step_S11_2 + psm_list_two_step_S11_3 + psm_list_two_step_S11_4

# %%
# Make sure all the decoys are correcly indicated
psm_list_F.find_decoys(r"REVERSED")
psm_list_S.find_decoys(r"REVERSED")
psm_list_two_step_F.find_decoys(r"REVERSED")
psm_list_two_step_S.find_decoys(r"REVERSED")

# %%
# Count the number of instances where is_decoy is True
true_count_F = sum(1 for psm in psm_list_F if psm.is_decoy == True)

# Count the number of instances where is_decoy is False
false_count_F = sum(1 for psm in psm_list_F if psm.is_decoy == False)

print(f'Number of decoys: {true_count_F}, Number of targets: {false_count_F}')
# Out:
# Number of decoys: 32977, Number of targets: 116056

# %%
# Count the number of instances where is_decoy is True and False
true_count_S = sum(1 for psm in psm_list_S if psm.is_decoy == True)
false_count_S = sum(1 for psm in psm_list_S if psm.is_decoy == False)
print(f'Number of decoys: {true_count_S}, Number of targets: {false_count_S}')
# Out:
# Number of decoys: 16555, Number of targets: 143040

# %%
# Count the number of instances where is_decoy is True and False
true_count_two_step_F = sum(1 for psm in psm_list_two_step_F if psm.is_decoy == True)
false_count_two_step_F = sum(1 for psm in psm_list_two_step_F if psm.is_decoy == False)
print(f'Number of decoys: {true_count_two_step_F}, Number of targets: {false_count_two_step_F}')
# Out:
# Number of decoys: 1208, Number of targets: 147551

# %%
# Count the number of instances where is_decoy is True and False
true_count_two_step_S = sum(1 for psm in psm_list_two_step_S if psm.is_decoy == True)
false_count_two_step_S = sum(1 for psm in psm_list_two_step_S if psm.is_decoy == False)
print(f'Number of decoys: {true_count_two_step_S}, Number of targets: {false_count_two_step_S}')
# Out:
# Number of decoys: 74920, Number of targets: 82075

# %%
# Turn psm_list into dataframes
psm_df_F = psm_list_F.to_dataframe()
psm_df_S = psm_list_S.to_dataframe()
psm_df_two_step_F = psm_list_two_step_F.to_dataframe()
psm_df_two_step_S = psm_list_two_step_S.to_dataframe()

# %%
psm_df_S
# Out:
#                                               peptidoform  \
# 0       ((I, None), (S, None), (I, None), (G, None), (...
# 1       ((I, None), (S, None), (I, None), (G, None), (...
# 2       ((I, None), (S, None), (I, None), (G, None), (...
# 3       ((T, None), (Y, None), (K, None), (P, None), (...
# 4       ((T, None), (Y, None), (K, None), (P, None), (...
# ...                                                   ...
# 159590  ((S, None), (L, None), (D, None), (V, None), (...
# 159591  ((G, None), (I, None), (S, None), (N, None), (...
# 159592  ((E, [+42.0106]), (K, None), (T, None), (G, No...
# 159593  ((F, None), (T, None), (M, None), (M, None), (...
# 159594  ((S, None), (P, None), (R, None), (N, None), (...
#
#                                               spectrum_id   run collection  \
# 0       controllerType=0 controllerNumber=1 scan=41124...  None       None
# 1       controllerType=0 controllerNumber=1 scan=41296...  None       None
# ...

# %%
# Calculate q values
psm_list_F.calculate_qvalues()
psm_list_S.calculate_qvalues()
psm_list_two_step_F.calculate_qvalues()
psm_list_two_step_S.calculate_qvalues()

# %%
# Inspect q value distribution

# Separate q-values based on is_decoy flag
q_values_target_F = [psm.qvalue for psm in psm_list_F if not psm.is_decoy]
q_values_decoy_F = [psm.qvalue for psm in psm_list_F if psm.is_decoy]

# Create histograms for is_decoy=True and is_decoy=False distributions
plt.figure(figsize=(10, 6))

plt.hist(q_values_target_F, bins=100, alpha=0.5, label='Target')
plt.hist(q_values_decoy_F, bins=100, alpha=0.5, label='Decoy')

plt.xlabel('q-values')
plt.xlim(0, 1)
plt.ylabel('frequency')
plt.title('q-value distribution F07')
plt.legend()
plt.grid(True)

plt.show()

# %%
#S

# Separate q-values based on is_decoy flag
q_values_target_S = [psm.qvalue for psm in psm_list_S if not psm.is_decoy]
q_values_decoy_S = [psm.qvalue for psm in psm_list_S if psm.is_decoy]

# Create histograms for is_decoy=True and is_decoy=False distributions
plt.figure(figsize=(10, 6))

plt.hist(q_values_target_S, bins=100, alpha=0.5, label='Target')
plt.hist(q_values_decoy_S, bins=100, alpha=0.5, label='Decoy')

plt.xlabel('q-values')
plt.xlim(0, 1)
plt.ylabel('frequency')
plt.title('q-value distribution S11')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Separate q-values based on is_decoy flag
q_values_target_F_two_step = [psm.qvalue for psm in psm_list_two_step_F if not psm.is_decoy]
q_values_decoy_F_two_step = [psm.qvalue for psm in psm_list_two_step_F if psm.is_decoy]

# Create histograms for is_decoy=True and is_decoy=False distributions
plt.figure(figsize=(10, 6))

plt.hist(q_values_target_F_two_step, bins=100, alpha=0.5, label='Target')
plt.hist(q_values_decoy_F_two_step, bins=100, alpha=0.5, label='Decoy')

plt.xlabel('q-values')
plt.xlim(0, 1)
plt.ylabel('frequency')
plt.title('q-value distribution two-step F07')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Separate q-values based on is_decoy flag
q_values_target_S_two_step = [psm.qvalue for psm in psm_list_two_step_S if not psm.is_decoy]
q_values_decoy_S_two_step = [psm.qvalue for psm in psm_list_two_step_S if psm.is_decoy]

# Create histograms for is_decoy=True and is_decoy=False distributions
plt.figure(figsize=(10, 6))

plt.hist(q_values_target_S_two_step, bins=100, alpha=0.5, label='Target')
plt.hist(q_values_decoy_S_two_step, bins=100, alpha=0.5, label='Decoy')

plt.xlabel('q-values')
plt.xlim(0, 1)
plt.ylabel('frequency')
plt.title('q-value distribution two-step S11')
plt.legend()
plt.grid(True)

plt.show()

# %%
# From https://github.com/compomics/psm_utils/blob/v0.7.1/online/_utils.py

import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from scipy import stats

class ECDF:
    """
    Return the Empirical CDF of an array as a step function.

    Parameters
    ----------
    x : array_like
        Observations
    """

    def __init__(self, x):
        # Get ECDF
        x = np.array(x, copy=True)
        x.sort()
        nobs = len(x)
        y = np.linspace(1.0 / nobs, 1, nobs)

        # Make into step function
        _x = np.asarray(x)
        _y = np.asarray(y)

        if _x.shape != _y.shape:
            msg = "x and y do not have the same shape"
            raise ValueError(msg)
        if len(_x.shape) != 1:
            msg = "x and y must be 1-dimensional"
            raise ValueError(msg)

        self.x = np.r_[-np.inf, _x]
        self.y = np.r_[0.0, _y]
        self.n = self.x.shape[0]

    def __call__(self, time):
        tind = np.searchsorted(self.x, time, side="right") - 1
        return self.y[tind]


def pp_plot(psm_df):
    """Generate PP plot for given PSM dataframe."""
    n_decoys = np.count_nonzero(psm_df["is_decoy"])
    n_targets = len(psm_df) - n_decoys
    pi_zero = n_decoys / n_targets
    if n_decoys == 0:
        raise ValueError("No decoy PSMs found in PSM file.")
    target_scores = psm_df["score"][~psm_df["is_decoy"]]
    decoy_scores = psm_df["score"][psm_df["is_decoy"]]
    if len(psm_df) > 1000:
        target_scores_quantiles = psm_df["score"][~psm_df["is_decoy"]].quantile(
            np.linspace(0, 1, 1000)
        )
    else:
        target_scores_quantiles = target_scores
    target_ecdf = ECDF(target_scores)(target_scores_quantiles)
    decoy_ecdf = ECDF(decoy_scores)(target_scores_quantiles)

    fig = go.Figure()
    fig.add_trace(
        go.Scatter(
            x=decoy_ecdf,
            y=target_ecdf,
            mode="markers",
        )
    )
    fig.add_trace(
        go.Scatter(
            x=[0, 1],
            y=[0, pi_zero],
            mode="lines",
            line=go.scatter.Line(color="red"),
            showlegend=True,
            name="pi0",
        )
    )
    # Calculate the slope of the red line
    red_line_slope = pi_zero

    # Calculate the slope of the best fit line for the scatter plot points up to x = 0.95
    mask = decoy_ecdf <= 0.95
    scatter_plot_slope, _, _, _, _ = stats.linregress(decoy_ecdf[mask], target_ecdf[mask])

    fig.update_layout(
        title = {
            'text': "P-P Plot S11",
            'y':0.9,
            'x':0.5,
            'xanchor': 'center',
            'yanchor': 'top',
            'font': dict(
                size=22,
                color="black"
            )
        },
        xaxis_title="Fdp",
        yaxis_title="Ftp",
        xaxis=dict(
        title_font=dict(
            size=18,  # Increase the x-axis title font size
        ),
        tickfont=dict(
            size=16,  # Increase the x-axis tick font size
        ),
    ),
    yaxis=dict(
        title_font=dict(
            size=18,  # Increase the y-axis title font size
        ),
        tickfont=dict(
            size=16,  # Increase the y-axis tick font size
        ),
    ),
        showlegend=False,
        autosize=False,
        width=1000,
        height=800,
        annotations=[
            go.layout.Annotation(
                x=0.05,
                y=0.95,
                xref="paper",
                yref="paper",
                text=f"Red line slope: {red_line_slope:.2f}<br>Scatter plot slope (up to x=0.95): {scatter_plot_slope:.2f}",
                showarrow=False,
                align="left",
                bgcolor="white",
                bordercolor="black",
                borderwidth=1,
                borderpad=4,
                font=dict(
                    size=16,  # Increase the annotation font size
                ),
            )
        ],
    )

    return fig

# %%
pp_plot(psm_df_F)
# Out:
# <div>                            <div id="cad1018b-209b-45a5-ab2e-c659af1c9702" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cad1018b-209b-45a5-ab2e-c659af1c9702")) {                    Plotly.newPlot(                        "cad1018b-209b-45a5-ab2e-c659af1c9702",                        [{"mode":"markers","x":[3.0324165327349365e-05,0.0029414440367528886,0.005185432270976741,0.008369469630348424,0.010825727021863723,0.013221336082724322,0.01579889013554902,0.01874033417230191,0.02201534402765564,0.025078084725717927,0.02820147375443491,0.0310822694605331,0.034114685993268036,0.03651029505412863,0.03972465657882766,0.04172605149043272,0.04363647390605573,0.047942505382539344,0.050671680262000786,0.05397701428268187,0.057342996634017644,0.0609515
# ...

# %%
pp_plot(psm_df_two_step_F)
# Out:
# <div>                            <div id="84e6f961-7a4b-4868-ae04-4267ff3bbde9" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84e6f961-7a4b-4868-ae04-4267ff3bbde9")) {                    Plotly.newPlot(                        "84e6f961-7a4b-4868-ae04-4267ff3bbde9",                        [{"mode":"markers","x":[0.0,0.0024834437086092716,0.0024834437086092716,0.004966887417218543,0.005794701986754967,0.008278145695364239,0.014072847682119206,0.015728476821192054,0.016556291390728478,0.018211920529801324,0.028145695364238412,0.03228476821192053,0.03394039735099338,0.03890728476821192,0.04139072847682119,0.04552980132450331,0.04718543046357616,0.05132450331125828,0.05380794701986755,0.06043046357615894,0.06539735099337748,0.07036423841059603,0.0753
# ...

# %%
pp_plot(psm_df_S)
# Out:
# <div>                            <div id="68159971-a9fa-4f7d-95ae-74beba22a692" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68159971-a9fa-4f7d-95ae-74beba22a692")) {                    Plotly.newPlot(                        "68159971-a9fa-4f7d-95ae-74beba22a692",                        [{"mode":"markers","x":[0.0,0.004349139232860163,0.008939897311990335,0.014557535487768045,0.020416792509815766,0.024645122319540923,0.0320749018423437,0.03871942011476895,0.04294774992449411,0.04844457867713681,0.05484747810329205,0.05955904560555723,0.06511627906976743,0.07176079734219268,0.07991543340380548,0.08523104802174569,0.0909090909090909,0.0960434913923286,0.10305043793415886,0.11060102688009664,0.11851404409543943,0.11851404409543943,0.12848082150407
# ...

# %%
pp_plot(psm_df_two_step_S)
# Out:
# <div>                            <div id="5f60de5c-f5e1-4399-8ca5-940302ce78cb" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f60de5c-f5e1-4399-8ca5-940302ce78cb")) {                    Plotly.newPlot(                        "5f60de5c-f5e1-4399-8ca5-940302ce78cb",                        [{"mode":"markers","x":[0.0,0.0009743726641751201,0.0023892151628403632,0.0032968499733048587,0.004151094500800854,0.005579284570208222,0.006473571809930593,0.007407901761879338,0.008235451147891084,0.008929524826481582,0.009783769353977578,0.010878270154831822,0.01209289909236519,0.01328083288841431,0.014722370528563802,0.015710090763481045,0.01651094500800854,0.01777896422851041,0.018539775760811533,0.019741057127602775,0.02094233849439402,0.022143619861185265
# ...
