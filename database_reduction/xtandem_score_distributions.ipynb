# %%
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 6.0 MB/s eta 0:00:0000:01
# ...

# %%
from psm_utils.io.xtandem import XTandemReader
from psm_utils.psm_list import PSMList
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read all target and decoy search files (normal search) for S11
tandem_f_target_S11_1 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction1.2024_03_07_11_24_16.t.xml"
tandem_f_target_S11_2 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction2.2024_03_07_11_24_47.t.xml"
tandem_f_target_S11_3 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction3.2024_03_07_11_25_17.t.xml"
tandem_f_target_S11_4 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction4.2024_03_07_11_25_36.t.xml"
tandem_f_decoy_S11_1 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction1_decoy.2024_03_07_11_27_19.t.xml"
tandem_f_decoy_S11_2 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction2_decoy.2024_03_07_11_27_37.t.xml"
tandem_f_decoy_S11_3 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction3_decoy.2024_03_07_11_27_57.t.xml"
tandem_f_decoy_S11_4 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction4_decoy.2024_03_07_11_28_09.t.xml"

reader_target_S11_1 = XTandemReader(tandem_f_target_S11_1)
reader_target_S11_2 = XTandemReader(tandem_f_target_S11_2)
reader_target_S11_3 = XTandemReader(tandem_f_target_S11_3)
reader_target_S11_4 = XTandemReader(tandem_f_target_S11_4)
reader_decoy_S11_1 = XTandemReader(tandem_f_decoy_S11_1)
reader_decoy_S11_2 = XTandemReader(tandem_f_decoy_S11_2)
reader_decoy_S11_3 = XTandemReader(tandem_f_decoy_S11_3)
reader_decoy_S11_4 = XTandemReader(tandem_f_decoy_S11_4)

psm_list_target_S11_1 = reader_target_S11_1.read_file()
psm_list_target_S11_2 = reader_target_S11_2.read_file()
psm_list_target_S11_3 = reader_target_S11_3.read_file()
psm_list_target_S11_4 = reader_target_S11_4.read_file()
psm_list_decoy_S11_1 = reader_decoy_S11_1.read_file()
psm_list_decoy_S11_2 = reader_decoy_S11_2.read_file()
psm_list_decoy_S11_3 = reader_decoy_S11_3.read_file()
psm_list_decoy_S11_4 = reader_decoy_S11_4.read_file()

# %%
# Read all target and decoy search files (normal search) for F07
tandem_f_target_F07_1 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction1.2024_03_08_15_28_35.t.xml"
tandem_f_target_F07_2 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction2.2024_03_08_15_48_31.t.xml"
tandem_f_target_F07_3 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction3.2024_03_08_16_10_26.t.xml"
tandem_f_target_F07_4 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction4.2024_03_08_16_30_50.t.xml"
tandem_f_decoy_F07_1 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction1_decoy.2024_03_05_19_28_44.t.xml"
tandem_f_decoy_F07_2 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction2_decoy.2024_03_05_19_36_54.t.xml"
tandem_f_decoy_F07_3 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction3_decoy.2024_03_05_19_45_43.t.xml"
tandem_f_decoy_F07_4 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction4_decoy.2024_03_05_19_53_59.t.xml"

reader_target_F07_1 = XTandemReader(tandem_f_target_F07_1)
reader_target_F07_2 = XTandemReader(tandem_f_target_F07_2)
reader_target_F07_3 = XTandemReader(tandem_f_target_F07_3)
reader_target_F07_4 = XTandemReader(tandem_f_target_F07_4)
reader_decoy_F07_1 = XTandemReader(tandem_f_decoy_F07_1)
reader_decoy_F07_2 = XTandemReader(tandem_f_decoy_F07_2)
reader_decoy_F07_3 = XTandemReader(tandem_f_decoy_F07_3)
reader_decoy_F07_4 = XTandemReader(tandem_f_decoy_F07_4)

psm_list_target_F07_1 = reader_target_F07_1.read_file()
psm_list_target_F07_2 = reader_target_F07_2.read_file()
psm_list_target_F07_3 = reader_target_F07_3.read_file()
psm_list_target_F07_4 = reader_target_F07_4.read_file()
psm_list_decoy_F07_1 = reader_decoy_F07_1.read_file()
psm_list_decoy_F07_2 = reader_decoy_F07_2.read_file()
psm_list_decoy_F07_3 = reader_decoy_F07_3.read_file()
psm_list_decoy_F07_4 = reader_decoy_F07_4.read_file()

# %%
# Read all target and decoy search files (two-step search) for S11
tandem_f_two_step_target_S11_1 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction1_2nd_step_target.2024_03_09_18_27_03.t.xml"
tandem_f_two_step_target_S11_2 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction2_2nd_step_target.2024_03_09_18_27_52.t.xml"
tandem_f_two_step_target_S11_3 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction3_2nd_step_target.2024_03_09_18_28_38.t.xml"
tandem_f_two_step_target_S11_4 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction4_2nd_step_target.2024_03_09_18_29_06.t.xml"
tandem_f_two_step_decoy_S11_1 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction1_2nd_step_decoy.2024_04_06_20_29_51.t.xml"
tandem_f_two_step_decoy_S11_2 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction2_2nd_step_decoy.2024_04_06_20_30_21.t.xml"
tandem_f_two_step_decoy_S11_3 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction3_2nd_step_decoy.2024_04_06_20_30_52.t.xml"
tandem_f_two_step_decoy_S11_4 = r"/home/wout/xtandem/output/normal_vs_two_step/S11_Fraction4_2nd_step_decoy.2024_04_06_20_31_12.t.xml"

reader_two_step_target_S11_1 = XTandemReader(tandem_f_target_S11_1)
reader_two_step_target_S11_2 = XTandemReader(tandem_f_target_S11_2)
reader_two_step_target_S11_3 = XTandemReader(tandem_f_target_S11_3)
reader_two_step_target_S11_4 = XTandemReader(tandem_f_target_S11_4)
reader_two_step_decoy_S11_1 = XTandemReader(tandem_f_decoy_S11_1)
reader_two_step_decoy_S11_2 = XTandemReader(tandem_f_decoy_S11_2)
reader_two_step_decoy_S11_3 = XTandemReader(tandem_f_decoy_S11_3)
reader_two_step_decoy_S11_4 = XTandemReader(tandem_f_decoy_S11_4)

psm_list_two_step_target_S11_1 = reader_two_step_target_S11_1.read_file()
psm_list_two_step_target_S11_2 = reader_two_step_target_S11_2.read_file()
psm_list_two_step_target_S11_3 = reader_two_step_target_S11_3.read_file()
psm_list_two_step_target_S11_4 = reader_two_step_target_S11_4.read_file()
psm_list_two_step_decoy_S11_1 = reader_two_step_decoy_S11_1.read_file()
psm_list_two_step_decoy_S11_2 = reader_two_step_decoy_S11_2.read_file()
psm_list_two_step_decoy_S11_3 = reader_two_step_decoy_S11_3.read_file()
psm_list_two_step_decoy_S11_4 = reader_two_step_decoy_S11_4.read_file()

# %%
# Read all target and decoy search files (two-step search) for F07
tandem_f_two_step_target_F07_1 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction1_2nd_step_target.2024_03_09_18_23_35.t.xml"
tandem_f_two_step_target_F07_2 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction2_2nd_step_target.2024_03_09_18_24_26.t.xml"
tandem_f_two_step_target_F07_3 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction3_2nd_step_target.2024_03_09_18_25_28.t.xml"
tandem_f_two_step_target_F07_4 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction4_2nd_step_target.2024_03_09_18_26_21.t.xml"
tandem_f_two_step_decoy_F07_1 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction1_2nd_step_decoy.2024_03_09_18_32_24.t.xml"
tandem_f_two_step_decoy_F07_2 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction2_2nd_step_decoy.2024_03_09_18_32_45.t.xml"
tandem_f_two_step_decoy_F07_3 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction3_2nd_step_decoy.2024_03_09_18_33_12.t.xml"
tandem_f_two_step_decoy_F07_4 = r"/home/wout/xtandem/output/normal_vs_two_step/F07_Fraction4_2nd_step_decoy.2024_03_09_18_33_33.t.xml"

reader_two_step_target_F07_1 = XTandemReader(tandem_f_target_F07_1)
reader_two_step_target_F07_2 = XTandemReader(tandem_f_target_F07_2)
reader_two_step_target_F07_3 = XTandemReader(tandem_f_target_F07_3)
reader_two_step_target_F07_4 = XTandemReader(tandem_f_target_F07_4)
reader_two_step_decoy_F07_1 = XTandemReader(tandem_f_decoy_F07_1)
reader_two_step_decoy_F07_2 = XTandemReader(tandem_f_decoy_F07_2)
reader_two_step_decoy_F07_3 = XTandemReader(tandem_f_decoy_F07_3)
reader_two_step_decoy_F07_4 = XTandemReader(tandem_f_decoy_F07_4)

psm_list_two_step_target_F07_1 = reader_two_step_target_F07_1.read_file()
psm_list_two_step_target_F07_2 = reader_two_step_target_F07_2.read_file()
psm_list_two_step_target_F07_3 = reader_two_step_target_F07_3.read_file()
psm_list_two_step_target_F07_4 = reader_two_step_target_F07_4.read_file()
psm_list_two_step_decoy_F07_1 = reader_two_step_decoy_F07_1.read_file()
psm_list_two_step_decoy_F07_2 = reader_two_step_decoy_F07_2.read_file()
psm_list_two_step_decoy_F07_3 = reader_two_step_decoy_F07_3.read_file()
psm_list_two_step_decoy_F07_4 = reader_two_step_decoy_F07_4.read_file()

# %%
# Concatenate the PSMs for each sample (keep target and decoy separate)
# Normal search
psm_list_target_S = psm_list_target_S11_1 + psm_list_target_S11_2 + psm_list_target_S11_3 + psm_list_target_S11_4
psm_list_decoy_S = psm_list_decoy_S11_1 + psm_list_decoy_S11_2 + psm_list_decoy_S11_3 + psm_list_decoy_S11_4
psm_list_target_F = psm_list_target_F07_1 + psm_list_target_F07_2 + psm_list_target_F07_3 + psm_list_target_F07_4
psm_list_decoy_F = psm_list_decoy_F07_1 + psm_list_decoy_F07_2 + psm_list_decoy_F07_3 + psm_list_decoy_F07_4

# Two-step
psm_list_two_step_target_S = psm_list_two_step_target_S11_1 + psm_list_two_step_target_S11_2 + psm_list_two_step_target_S11_3 + psm_list_two_step_target_S11_4
psm_list_two_step_decoy_S = psm_list_two_step_decoy_S11_1 + psm_list_two_step_decoy_S11_2 + psm_list_two_step_decoy_S11_3 + psm_list_two_step_decoy_S11_4
psm_list_two_step_target_F = psm_list_two_step_target_F07_1 + psm_list_two_step_target_F07_2 + psm_list_two_step_target_F07_3 + psm_list_two_step_target_F07_4
psm_list_two_step_decoy_F = psm_list_two_step_decoy_F07_1 + psm_list_two_step_decoy_F07_2 + psm_list_two_step_decoy_F07_3 + psm_list_two_step_decoy_F07_4

# %%
# Make sure targets and decoys are correctly assigned
for psm in psm_list_decoy_F:
    psm.is_decoy = True
for psm in psm_list_target_F:
    psm.is_decoy = False
for psm in psm_list_decoy_S:
    psm.is_decoy = True
for psm in psm_list_target_S:
    psm.is_decoy = False
for psm in psm_list_two_step_decoy_F:
    psm.is_decoy = True
for psm in psm_list_two_step_target_F:
    psm.is_decoy = False
for psm in psm_list_two_step_decoy_S:
    psm.is_decoy = True
for psm in psm_list_two_step_target_S:
    psm.is_decoy = False

# %%
# Combining target and decoy PSM lists into a single PSM list for each sample
psm_list_S = psm_list_target_S + psm_list_decoy_S
psm_list_F = psm_list_target_F + psm_list_decoy_F
psm_list_two_step_S = psm_list_two_step_target_S + psm_list_two_step_decoy_S
psm_list_two_step_F = psm_list_two_step_target_F + psm_list_two_step_decoy_F

# %%
# Check if the number of targets and decoys is correct

# Count the number of decoy PSMs
decoy_count_S = len(list(filter(lambda psm: psm.is_decoy, psm_list_S)))

# Count the number of target PSMs
target_count_S = len(list(filter(lambda psm: not psm.is_decoy, psm_list_S)))

print(f"Number of decoy PSMs: {decoy_count_S}")
print(f"Number of target PSMs: {target_count_S}")
# Out:
# Number of decoy PSMs: 151012
# Number of target PSMs: 159117

# %%
# Count the number of decoy PSMs
decoy_count_F = len(list(filter(lambda psm: psm.is_decoy, psm_list_F)))

# Count the number of target PSMs
target_count_F = len(list(filter(lambda psm: not psm.is_decoy, psm_list_F)))

print(f"Number of decoy PSMs: {decoy_count_F}")
print(f"Number of target PSMs: {target_count_F}")
# Out:
# Number of decoy PSMs: 148119
# Number of target PSMs: 148661

# %%
# Count the number of decoy PSMs
decoy_count_two_step_S = len(list(filter(lambda psm: psm.is_decoy, psm_list_two_step_S)))

# Count the number of target PSMs
target_count_two_step_S = len(list(filter(lambda psm: not psm.is_decoy, psm_list_two_step_S)))

print(f"Number of decoy PSMs: {decoy_count_two_step_S}")
print(f"Number of target PSMs: {target_count_two_step_S}")
# Out:
# Number of decoy PSMs: 151012
# Number of target PSMs: 159117

# %%
# Count the number of decoy PSMs
decoy_count_two_step_F = len(list(filter(lambda psm: psm.is_decoy, psm_list_two_step_F)))

# Count the number of target PSMs
target_count_two_step_F = len(list(filter(lambda psm: not psm.is_decoy, psm_list_two_step_F)))

print(f"Number of decoy PSMs: {decoy_count_two_step_F}")
print(f"Number of target PSMs: {target_count_two_step_F}")
# Out:
# Number of decoy PSMs: 148119
# Number of target PSMs: 148661

# %%
psm_list_S.calculate_qvalues()
psm_list_F.calculate_qvalues()
psm_list_two_step_S.calculate_qvalues()
psm_list_two_step_F.calculate_qvalues()

# %%
# Visualize S11 q value distribution

# Separate q-values based on is_decoy flag
q_values_target_S = [psm.qvalue for psm in psm_list_S if not psm.is_decoy]
q_values_decoy_S = [psm.qvalue for psm in psm_list_S if psm.is_decoy]

# Create histograms for is_decoy=True and is_decoy=False distributions
plt.figure(figsize=(10, 6))

plt.hist(q_values_target_S, bins=100, alpha=0.5, label='Target')
plt.hist(q_values_decoy_S, bins=100, alpha=0.5, label='Decoy')

plt.xlabel('q-values')
plt.xlim(0, 1)
plt.ylabel('frequency')
plt.title('q-value distribution S11')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Visualize F07 q value distribution

# Separate q-values based on is_decoy flag
q_values_target_F = [psm.qvalue for psm in psm_list_F if not psm.is_decoy]
q_values_decoy_F = [psm.qvalue for psm in psm_list_F if psm.is_decoy]

# Create histograms for is_decoy=True and is_decoy=False distributions
plt.figure(figsize=(10, 6))

plt.hist(q_values_target_F, bins=100, alpha=0.5, label='Target')
plt.hist(q_values_decoy_F, bins=100, alpha=0.5, label='Decoy')

plt.xlabel('q-values')
plt.xlim(0, 1)
plt.ylabel('frequency')
plt.title('q-value distribution F07')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Separate q-values based on is_decoy flag
q_values_target_two_step_S = [psm.qvalue for psm in psm_list_two_step_S if not psm.is_decoy]
q_values_decoy_two_step_S = [psm.qvalue for psm in psm_list_two_step_S if psm.is_decoy]

# Create histograms for is_decoy=True and is_decoy=False distributions
plt.figure(figsize=(10, 6))

plt.hist(q_values_target_two_step_S, bins=100, alpha=0.5, label='Target')
plt.hist(q_values_decoy_two_step_S, bins=100, alpha=0.5, label='Decoy')

plt.xlabel('q-values')
plt.xlim(0, 1)
plt.ylabel('frequency')
plt.title('q-value distribution S11 two-step')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Separate q-values based on is_decoy flag
q_values_target_two_step_F = [psm.qvalue for psm in psm_list_two_step_F if not psm.is_decoy]
q_values_decoy_two_step_F = [psm.qvalue for psm in psm_list_two_step_F if psm.is_decoy]

# Create histograms for is_decoy=True and is_decoy=False distributions
plt.figure(figsize=(10, 6))

plt.hist(q_values_target_two_step_F, bins=100, alpha=0.5, label='Target')
plt.hist(q_values_decoy_two_step_F, bins=100, alpha=0.5, label='Decoy')

plt.xlabel('q-values')
plt.xlim(0, 1)
plt.ylabel('frequency')
plt.title('q-value distribution F07 two-step')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Transform PSM lists into dataframes
psm_df_S = psm_list_S.to_dataframe()
psm_df_F = psm_list_F.to_dataframe()
psm_df_two_step_S = psm_list_two_step_S.to_dataframe()
psm_df_two_step_F = psm_list_two_step_F.to_dataframe()

# %%
# Calculate FDR for F07 and S11

#F07
# Sort dataframe by score in descending order
psm_df_F_sorted = psm_df_F.sort_values('score', ascending=False)

# Calculate cumulative number of decoy and target hits
psm_df_F_sorted['cumulative_decoy'] = psm_df_F_sorted['is_decoy'].cumsum()
psm_df_F_sorted['cumulative_total'] = psm_df_F_sorted['score'].expanding().count()

# Calculate FDR
psm_df_F_sorted['FDR'] = psm_df_F_sorted['cumulative_decoy'] / psm_df_F_sorted['cumulative_total']

# Find score at which FDR first falls below or equals to 1%
fdr_1_percent_score_F = psm_df_F_sorted[psm_df_F_sorted['FDR'] <= 0.01]['score'].min()

# %%
print(fdr_1_percent_score_F)
# Out:
# 5.654992310486769

# %%
#S11
# Sort dataframe by score in descending order
psm_df_S_sorted = psm_df_S.sort_values('score', ascending=False)

# Calculate cumulative number of decoy and target hits
psm_df_S_sorted['cumulative_decoy'] = psm_df_S_sorted['is_decoy'].cumsum()
psm_df_S_sorted['cumulative_total'] = psm_df_S_sorted['score'].expanding().count()

# Calculate FDR
psm_df_S_sorted['FDR'] = psm_df_S_sorted['cumulative_decoy'] / psm_df_S_sorted['cumulative_total']

# Find score at which FDR first falls below or equals to 1%
fdr_1_percent_score_S = psm_df_S_sorted[psm_df_S_sorted['FDR'] <= 0.01]['score'].min()

# %%
print(fdr_1_percent_score_S)
# Out:
# 5.713832810509702

# %%
#F07 two-step
# Sort dataframe by score in descending order
psm_df_two_step_F_sorted = psm_df_two_step_F.sort_values('score', ascending=False)

# Calculate cumulative number of decoy and target hits
psm_df_two_step_F_sorted['cumulative_decoy'] = psm_df_two_step_F_sorted['is_decoy'].cumsum()
psm_df_two_step_F_sorted['cumulative_total'] = psm_df_two_step_F_sorted['score'].expanding().count()

# Calculate FDR
psm_df_two_step_F_sorted['FDR'] = psm_df_two_step_F_sorted['cumulative_decoy'] / psm_df_two_step_F_sorted['cumulative_total']

# Find score at which FDR first falls below or equals to 1%
fdr_1_percent_score_two_step_F = psm_df_two_step_F_sorted[psm_df_two_step_F_sorted['FDR'] <= 0.01]['score'].min()

# %%
#S11 two-step
# Sort dataframe by score in descending order
psm_df_two_step_S_sorted = psm_df_two_step_S.sort_values('score', ascending=False)

# Calculate cumulative number of decoy and target hits
psm_df_two_step_S_sorted['cumulative_decoy'] = psm_df_two_step_S_sorted['is_decoy'].cumsum()
psm_df_two_step_S_sorted['cumulative_total'] = psm_df_two_step_S_sorted['score'].expanding().count()

# Calculate FDR
psm_df_two_step_S_sorted['FDR'] = psm_df_two_step_S_sorted['cumulative_decoy'] / psm_df_two_step_S_sorted['cumulative_total']

# Find score at which FDR first falls below or equals to 1%
fdr_1_percent_score_two_step_S = psm_df_two_step_S_sorted[psm_df_two_step_S_sorted['FDR'] <= 0.01]['score'].min()

# %%
print(fdr_1_percent_score_two_step_F)
print(fdr_1_percent_score_two_step_S)
# Out:
# 5.654992310486769
# 5.713832810509702

# %%
# Calculate identification rate for F07 and S11

# Identification rate defined as the ratio of correct hits (PSMs above the fdr_1_percent_score and not decoy) to the total number of target PSMs in the psm_df
correct_hits_F = psm_df_F[(psm_df_F['score'] > fdr_1_percent_score_F) & (psm_df_F['is_decoy'] == False)]
total_target_psms_F = psm_df_F[psm_df_F['is_decoy'] == False].shape[0]

identification_rate_F = len(correct_hits_F) / total_target_psms_F

# If you want it as a percentage
identification_rate_percent_F = identification_rate_F * 100


print(identification_rate_F)
print(identification_rate_percent_F)
# Out:
# 0.3147496653459885
# 31.474966534598853

# %%
# Identification rate defined as the ratio of correct hits (PSMs above the fdr_1_percent_score and not decoy) to the total number of target PSMs in the psm_df
correct_hits_S = psm_df_S[(psm_df_S['score'] > fdr_1_percent_score_S) & (psm_df_S['is_decoy'] == False)]
total_target_psms_S = psm_df_S[psm_df_S['is_decoy'] == False].shape[0]

identification_rate_S = len(correct_hits_S) / total_target_psms_S

# If you want it as a percentage
identification_rate_percent_S = identification_rate_S * 100

print(identification_rate_S)
print(identification_rate_percent_S)
# Out:
# 0.5798186240313732
# 57.98186240313732

# %%
# two-step

# Identification rate defined as the ratio of correct hits (PSMs above the fdr_1_percent_score and not decoy) to the total number of target PSMs in the psm_df
correct_hits_two_step_F = psm_df_two_step_F[(psm_df_two_step_F['score'] > fdr_1_percent_score_two_step_F) & (psm_df_two_step_F['is_decoy'] == False)]
total_target_psms_two_step_F = psm_df_two_step_F[psm_df_two_step_F['is_decoy'] == False].shape[0]

identification_rate_two_step_F = len(correct_hits_two_step_F) / total_target_psms_two_step_F

# If you want it as a percentage
identification_rate_percent_two_step_F = identification_rate_two_step_F * 100


print(identification_rate_two_step_F)
print(identification_rate_percent_two_step_F)
# Out:
# 0.3147496653459885
# 31.474966534598853

# %%
# two-step

# Identification rate defined as the ratio of correct hits (PSMs above the fdr_1_percent_score and not decoy) to the total number of target PSMs in the psm_df
correct_hits_two_step_S = psm_df_two_step_S[(psm_df_two_step_S['score'] > fdr_1_percent_score_two_step_S) & (psm_df_two_step_S['is_decoy'] == False)]
total_target_psms_two_step_S = psm_df_two_step_S[psm_df_two_step_S['is_decoy'] == False].shape[0]

identification_rate_two_step_S = len(correct_hits_two_step_S) / total_target_psms_two_step_S

# If you want it as a percentage
identification_rate_percent_two_step_S = identification_rate_two_step_S * 100

print(identification_rate_two_step_S)
print(identification_rate_percent_two_step_S)
# Out:
# 0.5798186240313732
# 57.98186240313732

# %%
# Visualized by lines instead of bars

#F
# Create separate dataframes for targets and decoys
target_df_F = psm_df_F[psm_df_F['is_decoy'] == False]
decoy_df_F = psm_df_F[psm_df_F['is_decoy'] == True]

# Calculate histograms
target_hist_F = np.histogram(target_df_F['score'], bins=50)
decoy_hist_F = np.histogram(decoy_df_F['score'], bins=50)

# Calculate bin centers
target_bin_centers_F = 0.5*(target_hist_F[1][1:] + target_hist_F[1][:-1])
decoy_bin_centers_F = 0.5*(decoy_hist_F[1][1:] + decoy_hist_F[1][:-1])

# Plot lines
plt.plot(target_bin_centers_F, target_hist_F[0], label='Target')
plt.plot(decoy_bin_centers_F, decoy_hist_F[0], label='Decoy')

# Add vertical line at 1% FDR score
plt.axvline(fdr_1_percent_score_F, color='r', linestyle='dashed', linewidth=2)

# Add labels and title
plt.xlabel('PSM Score')
plt.ylabel('Number of PSMs')
plt.title('PSM Score Distribution F07')

# Add grid
plt.grid(True, which='both', color='gray', linestyle='-', linewidth=0.5, alpha=0.3)

# Set y-ticks
plt.yticks(np.arange(0, max(target_hist_F[0].max(), decoy_hist_F[0].max()), 5000))

# Set x-ticks
plt.xticks(np.arange(0, max(target_df_F['score'].max(), decoy_df_F['score'].max()), 10))

# Add legend
plt.legend(loc='upper right')

# Add identification rate as text annotation
plt.text(0.60, 0.80, f'Identification Rate: {identification_rate_percent_F:.2f}%', transform=plt.gca().transAxes)

# Add text annotation for 1% FDR
plt.text(fdr_1_percent_score_F+0.1, plt.gca().get_ylim()[1]*0.93, '1% FDR', color='red', horizontalalignment='left')

# Show plot
plt.show()

# %%
#S
# Create separate dataframes for targets and decoys
target_df_S = psm_df_S[psm_df_S['is_decoy'] == False]
decoy_df_S = psm_df_S[psm_df_S['is_decoy'] == True]

# Calculate histograms
target_hist_S = np.histogram(target_df_S['score'], bins=50)
decoy_hist_S = np.histogram(decoy_df_S['score'], bins=50)

# Calculate bin centers
target_bin_centers_S = 0.5*(target_hist_S[1][1:] + target_hist_S[1][:-1])
decoy_bin_centers_S = 0.5*(decoy_hist_S[1][1:] + decoy_hist_S[1][:-1])

# Plot lines
plt.plot(target_bin_centers_S, target_hist_S[0], label='Target')
plt.plot(decoy_bin_centers_S, decoy_hist_S[0], label='Decoy')

# Add vertical line at 1% FDR score
plt.axvline(fdr_1_percent_score_S, color='r', linestyle='dashed', linewidth=2)

# Add labels and title
plt.xlabel('PSM Score')
plt.ylabel('Number of PSMs')
plt.title('PSM Score Distribution S11')

# Add grid
plt.grid(True, which='both', color='gray', linestyle='-', linewidth=0.5, alpha=0.3)

# Set y-ticks
plt.yticks(np.arange(0, max(target_hist_S[0].max(), decoy_hist_S[0].max()), 5000))

# Set x-ticks
plt.xticks(np.arange(0, max(target_df_S['score'].max(), decoy_df_S['score'].max()), 10))

# Add legend
plt.legend(loc='upper right')

# Add identification rate as text annotation
plt.text(0.60, 0.80, f'Identification Rate: {identification_rate_percent_S:.2f}%', transform=plt.gca().transAxes)

# Add text annotation for 1% FDR
plt.text(fdr_1_percent_score_S+0.1, plt.gca().get_ylim()[1]*0.95, '1% FDR', color='red', horizontalalignment='left')

# Show plot
plt.show()

# %%
# F two-step

# Create separate dataframes for targets and decoys
target_df_two_step_F = psm_df_two_step_F[psm_df_two_step_F['is_decoy'] == False]
decoy_df_two_step_F = psm_df_two_step_F[psm_df_two_step_F['is_decoy'] == True]

# Calculate histograms
target_hist_two_step_F = np.histogram(target_df_two_step_F['score'], bins=50)
decoy_hist_two_step_F = np.histogram(decoy_df_two_step_F['score'], bins=50)

# Calculate bin centers
target_bin_centers_two_step_F = 0.5*(target_hist_two_step_F[1][1:] + target_hist_two_step_F[1][:-1])
decoy_bin_centers_two_step_F = 0.5*(decoy_hist_two_step_F[1][1:] + decoy_hist_two_step_F[1][:-1])

# Plot lines
plt.plot(target_bin_centers_two_step_F, target_hist_two_step_F[0], label='Target')
plt.plot(decoy_bin_centers_two_step_F, decoy_hist_two_step_F[0], label='Decoy')

# Add vertical line at 1% FDR score
plt.axvline(fdr_1_percent_score_two_step_F, color='r', linestyle='dashed', linewidth=2)

# Add labels and title
plt.xlabel('PSM Score')
plt.ylabel('Number of PSMs')
plt.title('PSM Score Distribution F07 two-step search')

# Add grid
plt.grid(True, which='both', color='gray', linestyle='-', linewidth=0.5, alpha=0.3)

# Set y-ticks
plt.yticks(np.arange(0, max(target_hist_two_step_F[0].max(), decoy_hist_two_step_F[0].max()), 5000))

# Set x-ticks
plt.xticks(np.arange(0, max(target_df_two_step_F['score'].max(), decoy_df_two_step_F['score'].max()), 10))

# Add legend
plt.legend(loc='upper right')

# Add identification rate as text annotation
plt.text(0.60, 0.80, f'Identification Rate: {identification_rate_percent_two_step_F:.2f}%', transform=plt.gca().transAxes)

# Add text annotation for 1% FDR
plt.text(fdr_1_percent_score_two_step_F+0.1, plt.gca().get_ylim()[1]*0.95, '1% FDR', color='red', horizontalalignment='left')

# Show plot
plt.show()

# %%
# S two-step

# Create separate dataframes for targets and decoys
target_df_two_step_S = psm_df_two_step_S[psm_df_two_step_S['is_decoy'] == False]
decoy_df_two_step_S = psm_df_two_step_S[psm_df_two_step_S['is_decoy'] == True]

# Calculate histograms
target_hist_two_step_S = np.histogram(target_df_two_step_S['score'], bins=50)
decoy_hist_two_step_S = np.histogram(decoy_df_two_step_S['score'], bins=50)

# Calculate bin centers
target_bin_centers_two_step_S = 0.5*(target_hist_two_step_S[1][1:] + target_hist_two_step_S[1][:-1])
decoy_bin_centers_two_step_S = 0.5*(decoy_hist_two_step_S[1][1:] + decoy_hist_two_step_S[1][:-1])

# Plot lines
plt.plot(target_bin_centers_two_step_S, target_hist_two_step_S[0], label='Target')
plt.plot(decoy_bin_centers_two_step_S, decoy_hist_two_step_S[0], label='Decoy')

# Add vertical line at 1% FDR score
plt.axvline(fdr_1_percent_score_two_step_S, color='r', linestyle='dashed', linewidth=2)

# Add labels and title
plt.xlabel('PSM Score')
plt.ylabel('Number of PSMs')
plt.title('PSM Score Distribution S11 two-step search')

# Add grid
plt.grid(True, which='both', color='gray', linestyle='-', linewidth=0.5, alpha=0.3)

# Set y-ticks
plt.yticks(np.arange(0, max(target_hist_two_step_S[0].max(), decoy_hist_two_step_S[0].max()), 5000))

# Set x-ticks
plt.xticks(np.arange(0, max(target_df_two_step_S['score'].max(), decoy_df_two_step_S['score'].max()), 10))

# Add legend
plt.legend(loc='upper right')

# Add identification rate as text annotation
plt.text(0.60, 0.80, f'Identification Rate: {identification_rate_percent_two_step_S:.2f}%', transform=plt.gca().transAxes)

# Add text annotation for 1% FDR
plt.text(fdr_1_percent_score_two_step_S+0.1, plt.gca().get_ylim()[1]*0.95, '1% FDR', color='red', horizontalalignment='left')

# Show plot
plt.show()
